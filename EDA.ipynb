# %%
import pandas as pd
barbiedf= pd.read_csv('/Users/adelamar_ifds/barbiedatahouse/DATA/Barbies_Data.csv')
barbiedf.head(5)
# Out:
#    Unnamed: 0                                  Title Product #  Released  \
# 0           0                             Cinderella     16900      1996
# 1           1                           2019 Holiday     FXF01      2019
# 2           2                    The X-Files Giftset     19630      1998
# 3           3              Winter in New York Barbie     19429      1998
# 4           4  Holiday Visions Winter Fantasy Barbie     B2519      2003
#
#    Lowest  Average  Highest                                                URL
# 0       1     19.0       55  https://www.barbiedb.com/wp-content/uploads/20...
# 1       9     26.0       67  https://www.barbiedb.com/wp-content/uploads/20...
# 2      11     28.0       57  https://www.barbiedb.com/wp-content/uploads/20...
# 3       4     26.0      106  https://www.barbiedb.com/wp-content/uploads/20...
# 4       1     24.0       98  https://www.barbiedb.com/wp-content/uploads/20...

# %%
barbiedf.describe()
# Out:
#         Unnamed: 0     Released       Lowest      Average       Highest
# count  1110.000000  1110.000000  1110.000000   465.000000   1110.000000
# mean    554.500000  2005.025225    47.816216    95.812903    136.028829
# std     320.573704    11.308499    80.702040   166.505221    838.462752
# min       0.000000  1959.000000     1.000000     7.000000      1.000000
# 25%     277.250000  1999.000000    12.000000    22.000000     30.000000
# 50%     554.500000  2009.000000    20.000000    35.000000     50.000000
# 75%     831.750000  2013.000000    44.750000    86.000000    115.000000
# max    1109.000000  2020.000000   700.000000  1150.000000  27450.000000

# %%
barbiedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110 entries, 0 to 1109
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1110 non-null   int64
#  1   Title       1110 non-null   object
#  2   Product #   1110 non-null   object
#  3   Released    1110 non-null   int64
#  4   Lowest      1110 non-null   int64
#  5   Average     465 non-null    float64
#  6   Highest     1110 non-null   int64
#  7   URL         1110 non-null   object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 69.5+ KB

# %%
barbiedf.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Product #', 'Released', 'Lowest', 'Average',
#        'Highest', 'URL'],
#       dtype='object')

# %%
# Get the number of unique titles
num_unique_titles = barbiedf['Title'].nunique()
print(f"Number of unique titles: {num_unique_titles}")
# Out:
# Number of unique titles: 1071

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
from scipy.stats import ks_2samp
from scipy import stats


sns.histplot(barbiedf['Highest'],kde= True, color ='#e0218a')
sns.histplot(barbiedf['Lowest'], kde= True, color = '#ff6fff' )
plt.legend(loc= 'upper right', labels = ['Highest Barbie Cost','Lowest Barbie Cost'])
plt.title('Highest vs Lowest Barbie', fontsize=12, fontweight='normal')
# Out:
# Text(0.5, 1.0, 'Highest vs Lowest Barbie')

# %%
# Group data by title and calculate the count of each title
titlecounts = barbiedf['Title'].value_counts()

# Get the top 10 titles
top_20_titles = titlecounts.head(20)


# Create a bar chart with pink bars for the top 10 titles
plt.figure(figsize=(10, 6))
ax=top_20_titles.plot(kind='bar', color='#e0218a')
plt.title('Top 20 Collectible Barbies')
plt.xlabel('Barbies')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
ax.yaxis.set_major_locator(plt.MaxNLocator(integer=True))

plt.tight_layout()  
plt.tight_layout()

# Save the plot to a file
#plt.savefig('pink_top_10_titles.png')

# Show the plot
plt.show()

# %%
releasecounts = barbiedf['Released'].value_counts().sort_index()

# Create a bar plot for the counts of releases by year
plt.figure(figsize=(10, 6))
releasecounts.plot(kind='bar', color='#e0218a') 
plt.title('Barbie Releases by Year')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()


#plt.savefig('barbie_releases_by_year.png')

# Show the plot
plt.show()

# %%
# Select the columns for the scatter plot
xcolumn = 'Highest'
ycolumn = 'Lowest'

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(barbiedf[xcolumn], barbiedf[ycolumn], color='#e0218a', alpha=0.5)
plt.title(f'Scatter Plot of {xcolumn} vs {ycolumn}')
plt.xlabel(xcolumn)
plt.ylabel(ycolumn)
plt.grid(True)
plt.tight_layout()


#plt.savefig('barbie_scatter_plot.png')

# Show the plot
plt.show()

# %%
# Create a new DataFrame with 'Highest' and 'Lowest' columns
pricedf = barbiedf[['Highest', 'Lowest']]


# Create a pink-themed box plot for 'Highest' and 'Lowest' prices
plt.figure(figsize=(8, 6))
sns.boxplot(data=pricedf, color='#e0218a')
plt.title('Pink Box Plot of Barbie Doll Prices (Highest to Lowest)')
plt.ylabel('Price')
plt.xticks([0, 1], ['Highest', 'Lowest'])
plt.tight_layout()

# Save the plot to a file (optional)
#plt.savefig('pink_barbie_prices_box_plot.png')

# Show the plot
plt.show()
