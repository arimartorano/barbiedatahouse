# %%
# Importing libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import Image, HTML

# %%
titles = []
product_numbers = []
releases = []
lowest_prices = []
average_prices = []
highest_prices = []
barbie_url = []

# %%
url = 'https://www.barbiedb.com/'

response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    # Now, you can use Beautiful Soup methods to extract data from the page
    # For example, let's print the titles of all the articles on the page:
    for article in soup.find_all('article'):
        title = article.find('h2').text.strip()
        titles.append(title)
        release_year = article.find('label', class_='barbie__year').input['value']
        releases.append(release_year)
        product_number_final = article.find('label',class_='barbie__product_number').input['value']
        product_numbers.append(product_number_final)
        lowest_price = article.find('label', class_='barbie__value_lowest').input['value']
        lowest_prices.append(lowest_price)
        highest_price = article.find('label', class_='barbie__value_highest').input['value']
        highest_prices.append(highest_price)
        average_price = article.find('label', class_='barbie__value_average').input['value']
        average_prices.append(average_price)
        image_link = article.find('img',itemprop='image')
        image_url = image_link['data-src']
        barbie_url.append(image_url)
        print(product_number_final)
        print(title)
        print(average_price)
        print(highest_price)
        print(lowest_price)
        print(image_url)
       
        
else:
    print(f"Failed to fetch the page. Status code: {response.status_code}")
# Out:
# 16900
# Cinderella
# $19
# $55
# $1
# http://www.barbiedb.com/wp-content/uploads/2020/05/16900-cinderella-776x1024.jpg
# FXF01
# 2019 Holiday
# $26
# $67
# $9
# http://www.barbiedb.com/wp-content/uploads/2021/08/fxf01-2019-holiday.jpg
# 19630
# The X-Files Giftset
# $28
# $57
# $11
# http://www.barbiedb.com/wp-content/uploads/2021/08/19630-1998-the-x-files-giftset.jpg
# 19429
# Winter in New York Barbie
# $26
# $106
# $4
# http://www.barbiedb.com/wp-content/uploads/2021/07/19429-1998-winter-in-new-york-barbie.jpg
# B2519
# Holiday Visions Winter Fantasy Barbie
# $24
# $98
# $1
# http://www.barbiedb.com/wp-content/uploads/2021/05/holiday-visions-winter-fantasy-barbie.jpg

# %%
len(url)
# Out:
# 33

# %%
for i in range(2,223):
    url = f'https://www.barbiedb.com/page/{i}/'

    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        # Now, you can use Beautiful Soup methods to extract data from the page
        # For example, let's print the titles of all the articles on the page:
        for article in soup.find_all('article'):
            title = article.find('h2').text.strip()
            titles.append(title)
            release_year = article.find('label', class_='barbie__year').input['value']
            releases.append(release_year)
            product_number_final = article.find('label',class_='barbie__product_number').input['value']
            product_numbers.append(product_number_final)
            lowest_price = article.find('label', class_='barbie__value_lowest').input['value']
            lowest_prices.append(lowest_price)
            highest_price = article.find('label', class_='barbie__value_highest').input['value']
            highest_prices.append(highest_price)
            try:
                average_price_label = soup.find('label', class_='barbie__value_average')
                if average_price_label:
                    average_price = average_price_label.input['value']
                else:
                    average_price = None
            except AttributeError:
                average_price = None
            #average_price = article.find('label', class_='barbie__value_average').input['value']
            try:
                image_link = article.find('img', itemprop='image')
                if image_link:
                    image_link = article.find('img',itemprop='image')
                    image_url = image_link['data-src']
                else:
                    image_link = None
            except AttributeError:
                image_link = None
            average_prices.append(average_price)
            #image_link = article.find('img',itemprop='image')
            #image_url = image_link['data-src']
            barbie_url.append(image_url)
            #print(product_number_final)
            #print(title)
            #print(average_price)
            #print(highest_price)
            #print(lowest_price)
            #print(image_url)


    else:
        print(f"Failed to fetch the page. Status code: {response.status_code}")

# %%
# Create empty lists to store the extracted data

# %%
titles
# Out:
# ['Ralph Lauren Barbie',
#  'Ralph Lauren Barbie',
#  'Holiday Celebration Barbie',
#  '40th Anniversary Barbie',
#  '1959 The Original Teenage Fashion Model',
#  'Thai Barbie',
#  'Splash Of Silver Barbie',
#  'Pinch of Platinum Barbie',
#  'Happy Holidays Barbie 1997 Brunette',
#  'Flying Hero Barbie',
#  'Barbie Sign Language',
#  'Barbie Hallmark Keepsake Ornament 1994',
#  'Barbie 1999 Happy Holidays Club Edition Hallmark Ornament',
#  'Happy Holidays Barbie 1988',
#  'Evening Sophisticate Barbie',
#  'Water Lily Barbie',
#  'Special 2000 Edition Celebration Barbie (AA)',
#  'Happy Holidays Barbie',
#  'Bob Mackie Madame Du Barbie',
#  'Barbie Little Zoo Pals gift set with Stacie and Kelly',
#  'Barbie Fashion Fever Series Hilary Duff',
#  'NASCAR 50th Anniversary Barbie',
#  'Marisa Beach Baby Barbie',
#  'Jude Deveraux The Raider Barbie & Ken',
#  '50th Golden Anniversary of Mattel Barbie',
#  '2018 Holiday Barbie',
#  'Valentine Style Barbie',
#  'Victorian Lady',
#  'Scorpio Barbie',
#  'Registered Nurse Barbie',
#  'Radiant Rose Barbie',
#  'Midnight Gala Barbie',
#  'Lady of the White Woods Barbie',
#  'Harpist Angel Barbie',
#  'Bob Mackie The Charleston Barbie',
#  'Barbie as Marzipan in The Nutcracker',
#  'Barbie 30th Anniversary Francie',
#  'Flying Tinker Bell from Disney’s Peter Pan',
#  'Disney Favorites Barbie',
#  'Winter Renaissance Barbie',
#  '2017 Holiday Barbie',
#  'Workin’ Out',
#  'Special Occasion Barbie',
#  'Prince Ken',
#  'Special 2000 Edition Celebration Barbie',
#  'Holiday Ball Barbie',
#  'Happy Holidays Barbie',
#  'Barbie DC Comics – Lois Lane',
#  'Barbie Charm Girls Secret Spells',
#  'Barbie A Perfect Christmas Lead Doll',
#  '2013 Holiday Barbie Doll',
#  '2010 Holiday Barbie',
#  'Victorian Barbie with Cedric Bear',
#  'Valentine Barbie',
#  'Kool-Aid Wacky Warehouse Barbie',
#  'The Iris',
#  'Holiday Brunette Barbie Doll Kmart',
#  'Cali Guy So Excellent Earrings Blaine Doll',
#  'Barbie Becky I’m The School Photographer',
#  'Bella, from The Twilight Saga: Breaking Dawn (Part I)',
#  'Marilyn Monroe in Gentlemen Prefer Blondes',
#  'Barbie 1997 Children’s Collector Hallmark Keepsake Ornament Rapunzel',
#  'Angel Princess Barbie',
#  'The Peacock',
#  'Victorian Elegance',
#  'Barbie as Dorothy in The Wizard of Oz',
#  'Spanish Barbie',
#  'Student Teacher Barbie',
#  'Hollywood Cast Party Barbie',
#  'Barbie Paris Pretty Fashions Pretty City Looks',
#  'I Love Lucy, The Christmas Show',
#  'Timeless Silhouette 2000',
#  'Water Rhapsody',
#  'Ring in the New Year Barbie',
#  'Haunted Beauty Zombie Bride Barbie Doll',
#  'Bob Mackie Empress Bride Barbie',
#  '2020 Holiday Barbie',
#  'Teacher Barbie',
#  'Princess Barbie',
#  'Barbie Collector The Hunger Games: Mockingjay Part 2 Katniss',
#  'Barbie 2015 Holiday Doll',
#  'Sweet Treats Barbie',
#  'Enchanted Evening Barbie',
#  'Happy Birthday',
#  'Faberge Imperial Elegance Barbie',
#  'Elizabeth Taylor in Father of the Bride',
#  'Avon Mrs. P.F.E. Albee',
#  'Party Dress Barbie Doll',
#  'Parisienne Pretty Barbie',
#  'Nne Barbie',
#  'Libra Barbie',
#  'Fashion Fever Drew Doll',
#  'Barbie School Cool Teresa',
#  'Armani Barbie',
#  'Birthday Party Barbie',
#  'Winter Fantasy Barbie',
#  'Barbie as Wonder Woman',
#  'Winter Classic Barbie',
#  'Shanghai Barbie Doll',
#  'Roller Skating Ken',
#  'Hills Sea Pearl Mermaid Barbie',
#  'Happy Holidays Barbie 1993',
#  'Galadriel in The Lord of the Rings: The Fellowship of the Ring',
#  'Empress Sissy Barbie',
#  'Barbie President 2000',
#  'Barbie Paris Pretty Fashions',
#  'Barbie Fashion Avenue Lifestyles In-Line Skater Outfit',
#  'Barbie 2014 Holiday Doll with Ornament',
#  'Winter Fantasy Barbie',
#  'Shopping Chic Barbie – Spiegel',
#  'Walt Disney World Barbie',
#  'Midnight Princess Barbie',
#  'Czechoslovakian Barbie',
#  'Barbie Krissy Swing ‘n Play with AA Baby Krissy Doll',
#  'Barbie is Eternal Barbie',
#  'Barbie China',
#  'Barbie & The Diamond Castle Princess Liana Doll',
#  'Gymnast Barbie',
#  'Ken as The Tin Man in The Wizard of Oz',
#  'Kelly Doll and Friends, The Wizard of Oz Giftset',
#  'University of Texas Cheerleader Barbie',
#  'Winter Dazzle Barbie',
#  'Hollywood Legends Ken as Henry Higgins in My Fair Lady',
#  'Happy Holidays Barbie AA',
#  'Grolier Secret of the Three Teardrops Barbie',
#  'Emerald Enchantment Barbie',
#  'Barbie Princess Anneliese',
#  'Barbie Fashionistas Gown Sweetie Doll',
#  'Winter Fantasy Barbie',
#  'Diana Ross by Bob Mackie',
#  'Winter Fantasy Barbie',
#  'Whispering Wind Barbie',
#  'Barbie Traveling Sisters Gift Set',
#  'Mattel Barbie As The Island Princess Princess Rosella',
#  'Holiday Treasures Barbie 2001',
#  'Cracker Barrel Country Charm Barbie',
#  'Wedding Day Barbie',
#  'My Scene River',
#  'Snow White Barbie',
#  'Ken Fashion Avenue Student Sweater Outfit',
#  'The Munsters Giftset',
#  'Winter Moon, from Disney’s Pocahontas',
#  'Polish Barbie',
#  'Fashion Fever Drew Doll',
#  'Barbie Goldilocks and the Three Bears Kelly Storybook Collectible',
#  'Barbie Collectibles Hansel & Gretel Collector Edition',
#  'Barbie Halloween Enchantress',
#  'Byron Lars Coco Barbie',
#  'Yuletide Romance Barbie',
#  'Golden Anniversary Barbie',
#  'Tribal Beauty Barbie']

# %%
data = {
    'Title': titles,
    'Product #': product_numbers,
    'Released': releases,
    'Lowest': lowest_prices,
    'Average': average_prices,
    'Highest': highest_prices,
    'URL':barbie_url
}

df = pd.DataFrame.from_dict(data,orient='index')

# %%
df = df.transpose()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110 entries, 0 to 1109
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      1110 non-null   object
#  1   Product #  1110 non-null   object
#  2   Released   1110 non-null   object
#  3   Lowest     1110 non-null   object
#  4   Average    465 non-null    object
#  5   Highest    1110 non-null   object
#  6   URL        1110 non-null   object
# dtypes: object(7)
# memory usage: 60.8+ KB

# %%
df
# Out:
#                                             Title Product # Released Lowest  \
# 0                                      Cinderella     16900     1996     $1
# 1                                    2019 Holiday     FXF01     2019     $9
# 2                             The X-Files Giftset     19630     1998    $11
# 3                       Winter in New York Barbie     19429     1998     $4
# 4           Holiday Visions Winter Fantasy Barbie     B2519     2003     $1
# ...                                           ...       ...      ...    ...
# 1105  Barbie Cali Girl Pacific Beach Pool Playset     B5205     2003    $45
# 1106                    Barbie Cali Girl Lea Doll     G8666     2005    $25
# 1107                        Barbie Cali Girl Doll     68971     2004    $10
# 1108               Barbie Cali Girl Christie Doll     C6462     2004    $25
# 1109                   Barbie Cali Girl Chevy SSR     G6068     2004   $186
#
#      Average Highest                                                URL
# 0        $19     $55  http://www.barbiedb.com/wp-content/uploads/202...
# 1        $26     $67  http://www.barbiedb.com/wp-content/uploads/202...
# 2        $28     $57  http://www.barbiedb.com/wp-content/uploads/202...
# 3        $26    $106  http://www.barbiedb.com/wp-content/uploads/202...
# 4        $24     $98  http://www.barbiedb.com/wp-content/uploads/202...
# ...      ...     ...                                                ...
# 1105    None     $60  http://www.barbiedb.com/wp-content/uploads/202...
# 1106    None     $60  http://www.barbiedb.com/wp-content/uploads/202...
# 1107    None     $29  http://www.barbiedb.com/wp-content/uploads/202...
# 1108    None     $38  http://www.barbiedb.com/wp-content/uploads/202...
# 1109    None    $275  http://www.barbiedb.com/wp-content/uploads/202...
#
# [1110 rows x 7 columns]

# %%
df.to_csv("Barbies_Data.csv")

# %%
# Converting links to html tags
def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

# %%
HTML(df.to_html(escape=False,formatters=dict(URL=path_to_image_html)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Title</th>
#       <th>Product #</th>
#       <th>Released</th>
#       <th>Lowest</th>
#       <th>Average</th>
#       <th>Highest</th>
#       <th>URL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Cinderella</td>
#       <td>16900</td>
#       <td>1996</td>
#       <td>$1</td>
#       <td>$19</td>
#       <td>$55</td>
#       <td><img src="http://www.barbiedb.com/wp-content/uploads/2020/05/16900-cinderella-776x1024.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2019 Holiday</td>
#       <td>FXF01</td>
#       <td>2019</td>
#       <td>$9</td>
#       <td>$26</td>
#       <td>$67</td>
#       <td><img src="http://www.barbiedb.com/wp-content/uploads/2021/08/fxf01-2019-holiday.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>The X-Files Giftset</td>
#       <td>19630</td>
#       <td>1998</td>
#       <td>$11</td>
#       <td>$28</td>
#       <td>$57</td>
#       <td><img src="http://www.barbiedb.com/wp-content/uploads/2021/08/19630-1998-the-x-files-giftset.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Winter in New York Barbie</td>
#       <td>19429</td>
#       <td>1998</td>
#       <td>$4</td>
#       <td>$26</td>
#       <td>$106</td>
#       <td><img src="http://www.barbiedb.com/wp-content/uploads/2021/07/19429-1998-winter-in-new-york-barbie.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Holiday Visions Winter Fantasy Barbie</td>
#       <td>B2519</td>
#       <td>2003</td>
#       <td>$1</td>
#       <td>$24</td>
#       <td>$98</td>
#       <td><img src="http://www.barbiedb.com/wp-content/uploads/2021/05/holiday-visions-winter-fantasy-barbie.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Ralph Lauren Barbie</td>
#       <td>15950</td>
#       <td>1996</td>
#       <td>$21</td>
#       <td>$48</td>
#       <td>$76</td>
#       <td><img src="http://www.barbiedb.com/wp-content/uploads/2020/05/ralph-lauren-barbie.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Holiday Celebration Barbie</td>
#       <td>56209</td>
#       <td>2002</td>
#       <td>$1</td>
#       <td>$48</td>
#       <td>$51</td>
#       <td><img src="http://www.barbiedb.com/wp-content/uploads/2020/05/56209-2002-holiday-celebration-barbie-850x1024.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>40th Anniversary Barbie</td>
#       <td>21384</td>
#       <td>1999</td>
#       <td>$1</td>
#       <td>$48</td>
#       <td>$301</td>
#       <td><img src="http://www.barbiedb.com/wp-content/uploads/2020/05/40th-anniversary-barbie.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>