# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import numpy as np

df = pd.read_csv('DATA/Barbies_Data.csv')

# %%
#drop column 'Unnamed: 0', which is a duplicate of index
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
nltk.download('stopwords')
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/anastasiyaayala/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_text(text):
    text = re.sub(r'\W+', ' ', text.lower())
    words = [stemmer.stem(word) for word in text.split() if word not in stop_words]
    return ' '.join(words)

# %%
df
# Out:
#                                             Title Product #  Released  Lowest  \
# 0                                      Cinderella     16900      1996       1
# 1                                    2019 Holiday     FXF01      2019       9
# 2                             The X-Files Giftset     19630      1998      11
# 3                       Winter in New York Barbie     19429      1998       4
# 4           Holiday Visions Winter Fantasy Barbie     B2519      2003       1
# ...                                           ...       ...       ...     ...
# 1105  Barbie Cali Girl Pacific Beach Pool Playset     B5205      2003      45
# 1106                    Barbie Cali Girl Lea Doll     G8666      2005      25
# 1107                        Barbie Cali Girl Doll     68971      2004      10
# 1108               Barbie Cali Girl Christie Doll     C6462      2004      25
# 1109                   Barbie Cali Girl Chevy SSR     G6068      2004     186
#
#       Average  Highest                                                URL  \
# 0        19.0       55  https://www.barbiedb.com/wp-content/uploads/20...
# 1        26.0       67  https://www.barbiedb.com/wp-content/uploads/20...
# 2        28.0       57  https://www.barbiedb.com/wp-content/uploads/20...
# 3        26.0      106  https://www.barbiedb.com/wp-content/uploads/20...
# 4        24.0       98  https://www.barbiedb.com/wp-content/uploads/20...
# ...       ...      ...                                                ...
# 1105      NaN       60  https://www.barbiedb.com/wp-content/uploads/20...
# 1106      NaN       60  https://www.barbiedb.com/wp-content/uploads/20...
# 1107      NaN       29  https://www.barbiedb.com/wp-content/uploads/20...
# 1108      NaN       38  https://www.barbiedb.com/wp-content/uploads/20...
# 1109      NaN      275  https://www.barbiedb.com/wp-content/uploads/20...
#
#                                 processed_text  topic
# 0                                   cinderella      3
# 1                                 2019 holiday      5
# 2                               x file giftset      2
# 3                        winter new york barbi      1
# 4          holiday vision winter fantasi barbi      3
# ...                                        ...    ...
# 1105  barbi cali girl pacif beach pool playset      2
# 1106                  barbi cali girl lea doll      1
# 1107                      barbi cali girl doll      1
# 1108              barbi cali girl christi doll      1
# 1109                 barbi cali girl chevi ssr      2
#
# [1110 rows x 9 columns]

# %%
df['processed_text'] = df['Title'].apply(preprocess_text)

# Step 2: Vectorization
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['processed_text'])

# Step 3: Topic Modeling (using Gensim's LDA)
from gensim import corpora, models

dictionary = corpora.Dictionary(df['processed_text'].apply(lambda x: x.split()))
corpus = [dictionary.doc2bow(text.split()) for text in df['processed_text']]
lda_model = models.LdaModel(corpus, num_topics=6, id2word=dictionary, passes=10)

# Step 4: Assigning Labels
df['topic'] = [max(lda_model[text], key=lambda item: item[1])[0] for text in corpus]

# %%
topic2 = df[df['topic'] == 2]

# %%
topic2.head(40)
# Out:
#                                                  Title Product #  Released  \
# 2                                  The X-Files Giftset     19630      1998
# 7                              40th Anniversary Barbie     21384      1999
# 14                                Barbie Sign Language     25837      1999
# 18                         Evening Sophisticate Barbie     19361      1998
# 19                                   Water Lily Barbie     17783      1997
# 25                      NASCAR 50th Anniversary Barbie     20442      1998
# 28            50th Golden Anniversary of Mattel Barbie     14479      1995
# 37                                Harpist Angel Barbie     18894      1998
# 40                     Barbie 30th Anniversary Francie     14608      1996
# 58                     Kool-Aid Wacky Warehouse Barbie     11763      1994
# 69               Barbie as Dorothy in The Wizard of Oz     12701      1995
# 72                         Hollywood Cast Party Barbie     50825      2001
# 73      Barbie Paris Pretty Fashions Pretty City Looks      1909      1988
# 85                                 Sweet Treats Barbie     20780      1998
# 90                              Avon Mrs. P.F.E. Albee     17690      1997
# 91                             Party Dress Barbie Doll     W3425      2012
# 92                            Parisienne Pretty Barbie     N6594      2009
# 97                                       Armani Barbie     B2521      2003
# 107                               Empress Sissy Barbie     15846      1996
# 109                       Barbie Paris Pretty Fashions      6558      1989
# 121                                     Gymnast Barbie     12127      1993
# 122             Ken as The Tin Man in The Wizard of Oz     14902      1995
# 123   Kelly Doll and Friends, The Wizard of Oz Giftset     B2516      2003
# 129                         Emerald Enchantment Barbie     17443      1996
# 136                  Barbie Traveling Sisters Gift Set     14073      1995
# 141                                     My Scene River     B6696      2003
# 144                               The Munsters Giftset     50544      2001
# 149  Barbie Collectibles Hansel & Gretel Collector ...     28535      2000
# 153                          Golden Anniversary Barbie     20038      1998
# 164                          On Location: Milan Barbie     J0962      2006
# 170                Tales of the Arabian Nights Giftset     50827      2001
# 173                                Winter’s Eve Barbie     13613      1994
# 180                                      XXXOOO Barbie     23952      1999
# 181                                    Scottish Barbie      9845      1990
# 186                                   Barbie as Juliet     B5655      2004
# 199        Barbie Beach Blast Sunshine Holiday Playset      7393      1989
# 200                                  Stewardess Barbie     J4256      2006
# 216                          Harpist Angel Barbie (AA)     20551      1998
# 217                                    Carnaval Barbie     J0927      2006
# 221                                Locket Surprise Ken     10964      1993
#
#      Lowest  Average  Highest  \
# 2        11     28.0       57
# 7         1     48.0      301
# 14       17    301.0       73
# 18       10      8.0       70
# 19       23      8.0      101
# 25        1      9.0       29
# 28       15      9.0      200
# 37        9     21.0      100
# 40       22     42.0       70
# 58        1     28.0       31
# 69       17      7.0       66
# 72       12     19.0       50
# 73       11     19.0      151
# 85        7     18.0       38
# 90        2     14.0       75
# 91      100     14.0      400
# 92       90     14.0      731
# 97       49     70.0      400
# 107       9     25.0       66
# 109      24     25.0      223
# 121       5     66.0       37
# 122       3     66.0       40
# 123      21     66.0       51
# 129       5     15.0       40
# 136      29     35.0       85
# 141      17     19.0       33
# 144     187     19.0      300
# 149       3     39.0       51
# 153      14     16.0       80
# 164     132     21.0      341
# 170      98    110.0      175
# 173       2    110.0       44
# 180       6     14.0       30
# 73   barbi pari pretti fashion pretti citi look      2
# 85                            sweet treat barbi      2
# 90                           avon mr p f e albe      2
# 91                       parti dress barbi doll      2
# 92                       parisienn pretti barbi      2
# 97                                 armani barbi      2
# 107                         empress sissi barbi      2
# 109                   barbi pari pretti fashion      2
# 121                               gymnast barbi      2
# 122                       ken tin man wizard oz      2
# 123         kelli doll friend wizard oz giftset      2
# 129                       emerald enchant barbi      2
# 136                barbi travel sister gift set      2
# 141                                 scene river      2
# 144                             munster giftset      2
# 149  barbi collect hansel gretel collector edit      2
# 153                    golden anniversari barbi      2
# 164                           locat milan barbi      2
# 170                  tale arabian night giftset      2
# 173                            winter eve barbi      2
# 180                                xxxooo barbi      2
# 181                              scottish barbi      2
# 186                                barbi juliet      2
# 199   barbi beach blast sunshin holiday playset      2
# 200                            stewardess barbi      2
# 216                      harpist angel barbi aa      2
# 217                                carnav barbi      2
# 221                          locket surpris ken      2

# %% [markdown]
# <span style="color: #E0218A; font-size: 30px;"> Although it seems like ML model did very general categorization, it is easier to see certain patters in 'Barbie" titles. There is also overlap in categories.</span>

# %%
#create a new column for Barbies categories
df['category'] = np.nan

# %%
#create categories based on most common words
holiday = ['holiday','birthday',  'holidays', 'christmas', 'valentine', 'winter', 'new year', 'Ornament', 'Halloween']
ken = ['ken']
careers = ['careers', 'career', 'doctor','teacher', 'nurse', 'hostess','trainer', 'Photographer', 'dentist', 'babysitter', 'engineer', 'Entrepreneur', 'sitter','Barbie I Can Be','president','gymnast','model','Travel Agent', 'Stewardess','Video Girl','Music Star','Officer','Military Officer','Army Officer','Political','Public Service','Veterinarian','Astronaut','Transportation','Arts','Designer','Film director','Movie','actress','Hairdresser','Pet','TV Chef','Rockstar','Chef','Business','Sport','Football','Figure','Pediatrician','Harpist','Singer','Soccer',]
fashion_beauty = ['fashion_beauty','fashion','fashions',  'hair','elegance','Armani','pajama','Stylin','styling','salon','beauty','Corduroy','Ralph Lauren', 'chic','Wardrobe', 'dress', 'style', 'outfit']
vacation = ['vacation','beach', 'getaway','summer', 'Cruise'] 
horoscopes = ['horoscopes', 'aries', 'taurus', 'gemini', 'cancer', 'leo', 'virgo', 'libra', 'scorpio', 'sagittarius', 'capricorn', 'aquarius', 'pisces']
nationalities = [ 'nationalities', 'mexican', 'indian', 'chinese', 'japanese', 'brazilian', 'french', 'italian', 'australian', 'egyptian',
    'south african', 'russian', 'canadian', 'german', 'spanish', 'british', 'argentinian', 'chilean', 'colombian',
    'peruvian', 'venezuelan', 'greek', 'turkish', 'emirati', 'korean', 'malaysian', 'filipino', 'singaporean',
    'thai', 'vietnamese', 'new zealander', 'mexico', 'india', 'china', 'japan', 'brazil', 'france', 'italy', 'australia', 'egypt', 'south africa',
    'russia', 'canada', 'germany', 'spain', 'united kingdom', 'argentina', 'chile', 'colombia', 'peru', 'venezuela',
    'greece', 'turkey', 'united arab emirates', 'korea', 'malaysia', 'philippines', 'singapore', 'thailand',
    'vietnam', 'new zealand','Czechoslovakian','polish', 'Scottish', 'Native American', 'African American','Joie de Vivre Barbie']
special_occasion = ['special_occasion', 'ball', 'anniversary','Celebration', 'gala','Renaissance','occasion', 'party','wedding', 'Evening','silver','platinum', 'bride','Pepsi','']
animals = ['pets','animals', 'dog','horse', 'pony','pup', 'kittens','pet']
family_friends = ['family_friends', 'sister', 'sisters','friend', 'friends']
victorian = ['victorian']
celebrities = ['celebrities','Marilyn Monroe', 'Audrey Hepburn', 'Elizabeth Taylor', 'Grace Kelly', 'Beyoncé', 'Zendaya', 'Ava DuVernay', 'Ella Fitzgerald', 'Ibtihaj Muhammad', 'Yara Shahidi', 'Billie Jean King', 'Amelia Earhart', 'Florence Nightingale', 'Susan B. Anthony', 'Katherine Johnson', 'Ella Toone', 'Leyla Piedayesh']
california_girl = ['california_girl','cali','california']
movie_show_chars = ['movie_show_chars', 'disney', 'mermaid','cinderella','x-files','hunger games', 'wizard','nutcracker','twilight', 'princess', 'wonder woman', 'Hansel & Gretel', 'three bears', 'supergirl','fairy','Snow White','Juliet','Arabian Nights','Merliah','Pegasus','Three Musketeers', 'Three Musketeer', 'Alexa','The Secret Door', 'Curious George','Rebelde TV Barbie Doll','Daria Celebutante','Barbie Batgirl','Midge Wedding Day','Venetian Opulence','Benefit Performance Barbie']
cars = ['vehicles','Vehicle','cars', 'convertible', 'jeep','Converible','Speedboat','Microbus', 'Cadillac']
hobby_activity = ['hobby_activity','Keyboard','bike','Camping','Workin’ Out']
furniture = ['furniture','vanity', 'refrigerator', 'clock', 'appliance', 'closet', 'Kitchen','Bath','Telephone']
dreamhouse = ['houses','dreamhouse', 'house']
city_girl = ['city_girl','Shanghai', 'Parisienne', 'milan','new york']
cheerleader = ['cheerleader','Cheerleader']
famous = ['famous','music_artist', 'Diana Ross', 'Mia Hamm']
dining = ['dining', 'picnic', 'dinner','cafe', 'Yogurt', 'Ice Cream','Café']
royals =['royals','royal','Empress']
sets = ['sets','set']

# %%
categories = [holiday, ken, careers,fashion_beauty,vacation, horoscopes, nationalities, special_occasion, animals, family_friends, victorian, celebrities, california_girl, movie_show_chars, cars,hobby_activity, furniture, dreamhouse, city_girl, cheerleader,famous, dining,royals, sets]

# %%
for category in categories:
    filter = df['Title'].apply(lambda x: any(substring.lower() in x.lower() for substring in category))
    df.loc[filter, 'category'] = category[0]

# %%
df.groupby('category')['category'].count().sum()
# Out:
# 931

# %%
#barbies that still need to be categorized
missing = df[df['category'].isna()]

# %%
missing.tail(60)
# Out:
#       Unnamed: 0                                              Title Product #  \
# 482          482           Bedtime Baby Barbie Doll And Krissy Doll     56616
# 484          484                                Inuit Legend Barbie     G8892
# 1039        1039                         Barbie Fab Girl Assortment     T7584
# 1051        1051                             Barbie Doll Assortment     T7439
# 1055        1055     Barbie Doll & Accessory Gift Pack – Assortment     CML91
# 1061        1061               Barbie Dazzling Diva Light-Up Guitar    BE-639
# 1100        1100                Barbie Candy Glam Teresa Lemon Lime     N1471
# 1101        1101                           Barbie Candy Glam Teresa     N1471
#
#       Released  Lowest  Average  Highest  \
# 482       2002      41      NaN       70
# 484       2005     150      NaN      500
# 498       2000      70      NaN       95
# 499       2008      22      NaN       45
# 501       2013      25      NaN       40
# 512       1971     160      NaN      310
# 513       1970     450      NaN      650
# 517       2005      40      NaN       55
# 518       1964     450      NaN      525
# 524       1961     200      NaN      250
# 540       1972     225      NaN      300
# 572       1988      35      NaN       45
# 579       2014      22      NaN       34
# 581       1987      40      NaN       98
# 590       2015       6      NaN        9
# 591       2014      35      NaN       55
# 592       2015      20      NaN       25
# 601       2008      30      NaN       45
# 610       2013      21      NaN       30
# 621       1965     290      NaN      325
# 625       2006      35      NaN       71
# 629       2012      35      NaN       45
# 632       2007      45      NaN       80
# 635       1989      35      NaN       45
# 645       2003      25      NaN       70
# 665       2008     350      NaN      400
# 669       2015      75      NaN       80
# 679       1997     100      NaN      145
# 692       2004      45      NaN       55
# 693       2003     170      NaN      180
# 699       1995      70      NaN       80
# 700       2008     650      NaN      700
# 732       2010      26      NaN       37
# 734       2015      10      NaN       53
# 738       1996      70      NaN      150
# 747       1974      75      NaN       90
# 764       2012      12      NaN       15
# 775       1973     180      NaN      235
# 797       2012      12      NaN       16
# 799       2013      15      NaN       22
# 809       2008      22      NaN       47
# 810       2008      15      NaN       34
# 811       2006      44      NaN       60
# 829       2014      55      NaN       75
# 836       2013      23      NaN       45
# 850       2012     190      NaN      210
# 853       2013      13      NaN       20
# 870       2001      35      NaN       80
# 907       1995       8      NaN       27
# 925       2010      15      NaN       25
# 926       2009      14      NaN       25
# 931       2013      14      NaN       24
# 937       1977      90      NaN      125
# 939       1966     650      NaN      850
# 1039      2013      12      NaN       18
# 1051      2011      10      NaN       16
# 1055      2015      15      NaN       18
# 1061      2015      24      NaN       40
# 1100      2008      29      NaN       41
# 1101      2008      29      NaN       41
#
#                                                     URL category
# 482   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 484   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 498   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 499   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 501   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 512   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 513   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 517   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 518   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 524   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 540   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 572   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 579   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 581   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 590   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 591   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 592   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 601   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 610   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 621   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 625   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 629   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 632   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 635   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 645   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 665   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 669   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 679   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 692   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 693   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 699   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 700   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 732   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 734   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 738   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 747   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 764   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 775   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 797   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 799   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 809   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 810   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 811   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 829   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 836   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 850   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 853   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 870   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 907   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 925   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 926   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 931   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 937   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 939   https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 1039  https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 1051  https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 1055  https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 1061  https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 1100  https://www.barbiedb.com/wp-content/uploads/20...      NaN
# 1101  https://www.barbiedb.com/wp-content/uploads/20...      NaN
